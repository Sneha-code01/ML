# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/ML/blob/main/pyth_0_1csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
  #opening the local file
csv = pd.read_csv("/content/menu.csv")
  #opening through url code written in copy
  #sep parameter is used to run tsv files
tsv = pd.read_csv("/content/menu.csv",sep='\t')
