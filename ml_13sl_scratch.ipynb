# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/ML/blob/main/ml_13sl_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class scrachLR:

  def __init__(self):
    self.m = None
    self.b = None

  def fit(self,x_train,y_train):

    num = 0
    den = 0

    for i in range(x_train.shape[0])

  def predict(self,x_test):
    pass

# %%
import numpy as np
import pandas as pd
