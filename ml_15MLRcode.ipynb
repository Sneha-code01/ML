# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/ML/blob/main/ml_15MLRcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes
#sklearn gives the dataset in form of numpy array itself
X,y = load_diabetes(return_X_y = True)
X.shape
# Out:
# (442, 10)

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
#using sklearns linear regression
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=2)
print(X_train.shape)
print(X_test.shape)
# Out:
# (353, 10)
# (89, 10)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)
from sklearn.metrics import r2_score, mean_absolute_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568969

# %%
reg.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
#making our own linear regression class
class meraLR:
  def __init__(self):
    self.coef_ = None
    self.intercept_ = None

  def fit(self, X_train, y_train):
   X_train = np.insert(X_train,0,1,axis=1)

   #calculate the coeffs
   betas = np.linalg.pinv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
   #beyas is that multi formula
   self.intercept_ = betas[0]
   self.coed_ = betas[1:]

  def predict(self,X_test):
    y_pred = np.dot(X_test,self.coef_) + self.intercept_
    return y_pred

# %%
lr = meraLR()
X_train = np.insert(X_train,0,1,axis=1)
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6071/2763552447.py in <cell line: 0>()
#       2 X_train = np.insert(X_train,0,1,axis=1)
#       3 lr.fit(X_train,y_train)
# ----> 4 y_pred = lr.predict(X_test)
#       5 r2_score(y_test,y_pred)
#
# /tmp/ipykernel_6071/4062218517.py in predict(self, X_test)
#      15
#      16   def predict(self,X_test):
# ---> 17     y_pred = np.dot(X_test,self.coef_) + self.intercept_
#      18     return y_pred
#      19
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'
