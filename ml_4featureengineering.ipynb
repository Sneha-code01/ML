# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/ML/blob/main/ml_4featureengineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#feature scaling is a tecinque to standarize the independent features present in a data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df= pd.read_csv("/content/Social_Network_Ads.csv")
print(df.sample(5))
# Out:
#      Age  EstimatedSalary  Purchased
# 36    33            28000          0
# 226   36           126000          1
# 124   41            51000          0
# 304   40            60000          0
# 391   47            23000          1

# %%
#step1. train test split
x = df.iloc[:,0:2]
y = df.iloc[:,2]

from sklearn.model_selection import train_test_split
x_test,x_train,y_test,_y_train = train_test_split(x,y,test_size=0.3,random_state=0)

x_test.shape
# Out:
# (280, 2)

# %%
#step 2. Standard scalar
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(x_train)
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)
scaler.mean_
# Out:
# array([3.71666667e+01, 6.95916667e+04])
