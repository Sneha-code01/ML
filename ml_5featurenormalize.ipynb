# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/ML/blob/main/ml_5featurenormalize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("/content/wine_data.csv")
print(df[['class_label','alcohol','malic_acid']].sample(5))
# Out:
#      class_label  alcohol  malic_acid
# 166            3    13.45        3.70
# 157            3    12.45        3.03
# 167            3    12.82        3.37
# 54             1    13.74        1.67
# 86             2    12.16        1.61
