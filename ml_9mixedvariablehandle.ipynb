# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/ML/blob/main/ml_9mixedvariablehandle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/titanic.csv")['Ticket']
print(df.sample(3))
# Out:
# 473    SC/AH Basle 541
# 792           CA. 2343
# 577              13507
# Name: Ticket, dtype: object

# %%
df['num_ticket'] = pd.to_numeric(df['Ticket'],errors='coerce',downcast='integer')
df['alpha_ticket'] = np.where(df['num_ticket'].isnull(),df['Ticket'],np.nan)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1655/1086702243.py in <cell line: 0>()
# ----> 1 df['num_ticket'] = pd.to_numeric(df['Ticket'],errors='coerce',downcast='integer')
#       2 df['alpha_ticket'] = np.where(df['num_ticket'].isnull(),df['Ticket'],np.nan)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# ...
